# %%
from run import DATASET_CONFIG, run_net_to_odd_compilation, run_encoding, test_if_cnf_satisfiable, read_cnf_from_json, run_plot_odd
import json

successful_compilations = []
base_path = 'bnc_configs/'
config_paths = [
    'admission.json',
    # 'asia.json',
    # 'child.json',
    # 'coricalaz.json',
    # 'alarm.json',
    # 'win95pts.json',
]

for path in config_paths:
    path = base_path + path
    with open(path, 'r') as f:
        config = json.load(f)
    
    name = config['name']
    id = config['id']
    config['leaves'] = []
    success = run_net_to_odd_compilation(name, config)
    successful_compilations.append(success)
    print(f'Compilation success: {success}')
    
    if success:
        odd_filename = f"odd_models/{name}_{id}.odd"
        cnf_filename = f"cnf_files/{name}_{id}.json"
        run_encoding(odd_filename, cnf_filename)
        
        cnf, _, _, _ = read_cnf_from_json(cnf_filename)
        test_if_cnf_satisfiable(cnf=cnf)
        
        run_plot_odd(odd_filename=odd_filename, save_path=f'plots/{name}_{id}.png')
        
    print(f'Finished {name}_{id}')
    
print(f'Successful compilations: {successful_compilations}')
# Out:
# javac -d exe -sourcepath src -cp samiam:samiam/inflib.jar:include/* -Xlint:unchecked  src/RunCompiler.java src/TestOdd.java src/bnccompiler/core/OrderHeuristic.java src/bnccompiler/core/BayesianNetworkClassifier.java src/bnccompiler/core/BayesianNetworkClassifierToOdd.java src/bnccompiler/core/BayesianNetworkClassifierCompilationOrder.java src/bnccompiler/core/DecisionKey.java src/bnccompiler/core/OddNode.java src/bnccompiler/CompileClassifierConfig.java src/bnccompiler/CompileClassifier.java
# g++ -std=c++0x -Wno-sign-compare -O2 -Wall -I./include   -c -o src/oddtosdd.o src/oddtosdd.cpp
# g++ -std=c++0x -Wno-sign-compare -O2 -Wall -I./include src/oddtosdd.o -L./lib -lsdd -lm -o exe/oddtosdd
# /usr/bin/ld: ./lib/libsdd.a(manager.o): relocation R_X86_64_32 against `.rodata' can not be used when making a PIE object; recompile with -fPIE
# /usr/bin/ld: failed to set dynamic section sizes: bad value
# collect2: error: ld returned 1 exit status
# make: *** [Makefile:13: all] Error 1
# -----Print Compilation Order-----
# h_order:
# {"Admit"}
# {"Admit"}
# {"Admit"}
#
# feature_order:
# {"GPA","WorkExperience"}
#
# block_order:
# {}
# {"GPA"}
# {"WorkExperience"}
#
# node_order:
# {"Admit","GPA","WorkExperience"}
# {"Admit","WorkExperience"}
# {"Admit"}
# -----End Compilation Order-----
#  instance: [0]
#  instance: [1]
# instance: []
# admission & Admit & 2 & 2 & 1 & 2 & 3 & 0\\
# Instance	ODD verdict	Classification	Classifier Posterior Odds
# All instances pass :)
# Count brute force: 1
# Compilation success: True
# /home/ignacy/miniconda3/envs/cmu/lib/python3.10/site-packages/numpy/core/getlimits.py:518: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/ignacy/miniconda3/envs/cmu/lib/python3.10/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# Finished admission_1
# javac -d exe -sourcepath src -cp samiam:samiam/inflib.jar:include/* -Xlint:unchecked  src/RunCompiler.java src/TestOdd.java src/bnccompiler/core/OrderHeuristic.java src/bnccompiler/core/BayesianNetworkClassifier.java src/bnccompiler/core/BayesianNetworkClassifierToOdd.java src/bnccompiler/core/BayesianNetworkClassifierCompilationOrder.java src/bnccompiler/core/DecisionKey.java src/bnccompiler/core/OddNode.java src/bnccompiler/CompileClassifierConfig.java src/bnccompiler/CompileClassifier.java
# g++ -std=c++0x -Wno-sign-compare -O2 -Wall -I./include   -c -o src/oddtosdd.o src/oddtosdd.cpp
# g++ -std=c++0x -Wno-sign-compare -O2 -Wall -I./include src/oddtosdd.o -L./lib -lsdd -lm -o exe/oddtosdd
# /usr/bin/ld: ./lib/libsdd.a(manager.o): relocation R_X86_64_32 against `.rodata' can not be used when making a PIE object; recompile with -fPIE
# /usr/bin/ld: failed to set dynamic section sizes: bad value
# collect2: error: ld returned 1 exit status
# make: *** [Makefile:13: all] Error 1
# -----Print Compilation Order-----
# h_order:
# {"Bronchitis"}
# {"TbOrCa"}
# {"TbOrCa"}
#
# feature_order:
# {"Dyspnea","XRay"}
#
# block_order:
# {}
# {"Dyspnea"}
# {"XRay"}
#
# node_order:
# {"VisitToAsia","Smoking","Tuberculosis","Bronchitis","LungCancer","TbOrCa","Dyspnea","XRay"}
# {"TbOrCa","XRay"}
# {"TbOrCa"}
# -----End Compilation Order-----
#  instance: [0]
#  instance: [1]
# instance: []
# asia & Bronchitis & 2 & 2 & 1 & 2 & 3 & 0\\
# Instance	ODD verdict	Classification	Classifier Posterior Odds
# All instances pass :)
# Count brute force: 2
# Compilation success: True
# Finished asia_1
# javac -d exe -sourcepath src -cp samiam:samiam/inflib.jar:include/* -Xlint:unchecked  src/RunCompiler.java src/TestOdd.java src/bnccompiler/core/OrderHeuristic.java src/bnccompiler/core/BayesianNetworkClassifier.java src/bnccompiler/core/BayesianNetworkClassifierToOdd.java src/bnccompiler/core/BayesianNetworkClassifierCompilationOrder.java src/bnccompiler/core/DecisionKey.java src/bnccompiler/core/OddNode.java src/bnccompiler/CompileClassifierConfig.java src/bnccompiler/CompileClassifier.java
# g++ -std=c++0x -Wno-sign-compare -O2 -Wall -I./include   -c -o src/oddtosdd.o src/oddtosdd.cpp
# g++ -std=c++0x -Wno-sign-compare -O2 -Wall -I./include src/oddtosdd.o -L./lib -lsdd -lm -o exe/oddtosdd
# /usr/bin/ld: ./lib/libsdd.a(manager.o): relocation R_X86_64_32 against `.rodata' can not be used when making a PIE object; recompile with -fPIE
# /usr/bin/ld: failed to set dynamic section sizes: bad value
# collect2: error: ld returned 1 exit status
# make: *** [Makefile:13: all] Error 1
# -----Print Compilation Order-----
# h_order:
# {"Disease"}
# {"Disease"}
# {"LungParench"}
# {"CO2"}
# {"CO2"}
#
# feature_order:
# {"LVHreport","RUQO2","LowerBodyO2","XrayReport","Age","GruntingReport","CO2Report"}
#
# block_order:
# {}
# {"LVHreport"}
# {"RUQO2","LowerBodyO2","XrayReport","Age","GruntingReport"}
# {}
# {"CO2Report"}
#
# node_order:
# {"BirthAsphyxia","Disease","LVH","DuctFlow","Sick","CardiacMixing","LungParench","LungFlow","LVHreport","Age","HypDistrib","Grunting","HypoxiaInO2","CO2","ChestXray","GruntingReport","RUQO2","LowerBodyO2","CO2Report","XrayReport"}
# {"Disease","DuctFlow","Sick","CardiacMixing","LungParench","LungFlow","Age","HypDistrib","Grunting","HypoxiaInO2","CO2","ChestXray","GruntingReport","RUQO2","LowerBodyO2","CO2Report","XrayReport"}
# {"LungParench","CO2","CO2Report"}
# {"CO2","CO2Report"}
# {"CO2"}
# -----End Compilation Order-----
#     instance: [0, 0, 0, 0]
#     instance: [0, 0, 0, 1]
#     instance: [0, 0, 0, 2]
#     instance: [0, 0, 0, 3]
#     instance: [0, 0, 0, 4]
#    instance: [0, 0, 0]
#     instance: [0, 0, 1, 0]
#     instance: [0, 0, 1, 1]
#     instance: [0, 0, 1, 2]
#     instance: [0, 0, 1, 3]
#     instance: [0, 0, 1, 4]
#    instance: [0, 0, 1]
#     instance: [0, 0, 2, 0]
#     instance: [0, 0, 2, 1]
#     instance: [0, 0, 2, 2]
#     instance: [0, 0, 2, 3]
#     instance: [0, 0, 2, 4]
#    instance: [0, 0, 2]
#   instance: [0, 0]
#     instance: [0, 1, 0, 0]
#     instance: [0, 1, 0, 1]
#     instance: [0, 1, 0, 2]
#     instance: [0, 1, 0, 3]
#     instance: [0, 1, 0, 4]
#    instance: [0, 1, 0]
#     instance: [0, 1, 1, 0]
#     instance: [0, 1, 1, 1]
#     instance: [0, 1, 1, 2]
#     instance: [0, 1, 1, 3]
#     instance: [0, 1, 1, 4]
#    instance: [0, 1, 1]
#     instance: [0, 1, 2, 0]
#     instance: [0, 1, 2, 1]
#     instance: [0, 1, 2, 2]
#     instance: [0, 1, 2, 3]
#     instance: [0, 1, 2, 4]
#    instance: [0, 1, 2]
#   instance: [0, 1]
#     instance: [0, 2, 0, 0]
#     instance: [0, 2, 0, 1]
#     instance: [0, 2, 0, 2]
#     instance: [0, 2, 0, 3]
#     instance: [0, 2, 0, 4]
#    instance: [0, 2, 0]
#     instance: [0, 2, 1, 0]
#     instance: [0, 2, 1, 1]
#     instance: [0, 2, 1, 2]
#     instance: [0, 2, 1, 3]
#     instance: [0, 2, 1, 4]
#    instance: [0, 2, 1]
#     instance: [0, 2, 2, 0]
#     instance: [0, 2, 2, 1]
#     instance: [0, 2, 2, 2]
#     instance: [0, 2, 2, 3]
#     instance: [0, 2, 2, 4]
#    instance: [0, 2, 2]
#   instance: [0, 2]
#  instance: [0]
#     instance: [1, 0, 0, 0]
#     instance: [1, 0, 0, 1]
#     instance: [1, 0, 0, 2]
#     instance: [1, 0, 0, 3]
#     instance: [1, 0, 0, 4]
#    instance: [1, 0, 0]
#     instance: [1, 0, 1, 0]
#     instance: [1, 0, 1, 1]
#     instance: [1, 0, 1, 2]
#     instance: [1, 0, 1, 3]
#     instance: [1, 0, 1, 4]
#    instance: [1, 0, 1]
#     instance: [1, 0, 2, 0]
#     instance: [1, 0, 2, 1]
#     instance: [1, 0, 2, 2]
#     instance: [1, 0, 2, 3]
#     instance: [1, 0, 2, 4]
#    instance: [1, 0, 2]
#   instance: [1, 0]
#     instance: [1, 1, 0, 0]
#     instance: [1, 1, 0, 1]
#     instance: [1, 1, 0, 2]
#     instance: [1, 1, 0, 3]
#     instance: [1, 1, 0, 4]
#    instance: [1, 1, 0]
#     instance: [1, 1, 1, 0]
#     instance: [1, 1, 1, 1]
#     instance: [1, 1, 1, 2]
#     instance: [1, 1, 1, 3]
#     instance: [1, 1, 1, 4]
#    instance: [1, 1, 1]
#     instance: [1, 1, 2, 0]
#     instance: [1, 1, 2, 1]
#     instance: [1, 1, 2, 2]
#     instance: [1, 1, 2, 3]
#     instance: [1, 1, 2, 4]
#    instance: [1, 1, 2]
#   instance: [1, 1]
#     instance: [1, 2, 0, 0]
#     instance: [1, 2, 0, 1]
#     instance: [1, 2, 0, 2]
#     instance: [1, 2, 0, 3]
#     instance: [1, 2, 0, 4]
#    instance: [1, 2, 0]
#     instance: [1, 2, 1, 0]
#     instance: [1, 2, 1, 1]
#     instance: [1, 2, 1, 2]
#     instance: [1, 2, 1, 3]
#     instance: [1, 2, 1, 4]
#    instance: [1, 2, 1]
#     instance: [1, 2, 2, 0]
#     instance: [1, 2, 2, 1]
#     instance: [1, 2, 2, 2]
#     instance: [1, 2, 2, 3]
#     instance: [1, 2, 2, 4]
#    instance: [1, 2, 2]
#   instance: [1, 2]
#  instance: [1]
# instance: []
# child & Disease & 7 & 6 & 5 & 4 & 7 & 2\\
# Instance	ODD verdict	Classification	Classifier Posterior Odds
# All instances pass :)
# Count brute force: 0
# Compilation success: True
# Finished child_1
# javac -d exe -sourcepath src -cp samiam:samiam/inflib.jar:include/* -Xlint:unchecked  src/RunCompiler.java src/TestOdd.java src/bnccompiler/core/OrderHeuristic.java src/bnccompiler/core/BayesianNetworkClassifier.java src/bnccompiler/core/BayesianNetworkClassifierToOdd.java src/bnccompiler/core/BayesianNetworkClassifierCompilationOrder.java src/bnccompiler/core/DecisionKey.java src/bnccompiler/core/OddNode.java src/bnccompiler/CompileClassifierConfig.java src/bnccompiler/CompileClassifier.java
# g++ -std=c++0x -Wno-sign-compare -O2 -Wall -I./include   -c -o src/oddtosdd.o src/oddtosdd.cpp
# g++ -std=c++0x -Wno-sign-compare -O2 -Wall -I./include src/oddtosdd.o -L./lib -lsdd -lm -o exe/oddtosdd
# /usr/bin/ld: ./lib/libsdd.a(manager.o): relocation R_X86_64_32 against `.rodata' can not be used when making a PIE object; recompile with -fPIE
# /usr/bin/ld: failed to set dynamic section sizes: bad value
# collect2: error: ld returned 1 exit status
# make: *** [Makefile:13: all] Error 1
